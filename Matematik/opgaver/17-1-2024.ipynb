# %% [markdown]
# <p>Uploader i Jupiter Notebook, har ikke lige tid til at finde ud af hvad der er galt. Men her er fejlen. Googlede det lige kort, og har forsøgt at geninstalere quarto hvilket ikke gjorde noget.<p/>
#
# ![](attachment:image.png)

# %% [markdown]
# # Basisopgave 4.7
#
# 1. $\text{x - 2a = a}$<br/><br/>
# $\text{x - 2a + 2a = a + 2a}$<br/><br/>
# $\text{x = 3a}$
# <br/>
# <br/>
# <br/>
#
# 2. $\text{Ax + 1 = 0}$<br/><br/>
# $\text{A = -x}$<br/><br/>
# $\text{x =}\dfrac{-1}{A}$
# <br/>
# <br/>
# <br/>
#
# 3. $-(\dfrac{13}{14})x=\dfrac{12}{11} $<br/><br/>
# $-\dfrac{14}{13} \cdot (-\dfrac{13}{14}) x = -\dfrac{14}{13} \cdot \dfrac{12}{11}$<br/><br/>
# $x = \dfrac{168}{143}$
# <br/>
# <br/>
# <br/>
#
# 4. $(\dfrac{3}{7})x = 6$<br/><br/>
# $(\dfrac{3}{7}) \cdot \dfrac{7}{3}x = 6 \cdot \dfrac{7}{3}$<br/><br/>
# $\text{x = 14}$
# <br/>
# <br/>
# <br/>
#
# 5. $\dfrac{1}{x}-(2a+3)=1$<br><br>
# $\dfrac{1}{x} = 1 + 2a + 3$<br><br>
# $\text{x = } \dfrac{1}{2a+4}$

# %% [markdown]
# ![](attachment:image.png)
#
# $l: y = 7x + 15$<br><br>
# $c: (x - 8)^2 + (y - 9)^2 = 121$<br><br>
# $\text{Cirklens, c har centrum i (8, 9) og radius } \sqrt{121}$<br><br>
# $(x - 8)^2 + (7x+15-9)^2 = 121$<br><br>
# $(x - 8)^2 + (7x+6)^2 = 121$<br><br>

# %%
from gym_cas import *


tissemand = Sin(56) + 44
print(tissemand)
